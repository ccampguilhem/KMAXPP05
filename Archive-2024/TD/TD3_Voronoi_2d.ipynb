# %%
from scipy.spatial import Voronoi,voronoi_plot_2d;
import numpy as np
import numpy.random as npr
import matplotlib.pyplot as plt
# Out:
# 3.141592653589793

# %%
n=4;
m=4;
ptsx=np.linspace(0,n,n+1);
ptsy=np.linspace(0,m,m+1);
pts=[ptsx,ptsy];
print(pts)
#vor=Voronoi(pts);
#voronoi_plot_2d(vor);
#plt.show();
# Out:
# nombre de points abscisses3
# nombre de points ordonnées3
# [array([0., 1., 2., 3.]), array([0., 1., 2., 3.])]

# %%
n=4;
angle=np.linspace(0,2*np.pi*(1-1/n),n)
print(angle)
pts=[np.cos(angle),np.sin(angle)];
print(pts)
#vor=Voronoi(pts);
#voronoi_plot_2d(vor);
#plt.show();
# Out:
# [0.         1.57079633 3.14159265 4.71238898]
# [array([ 1.0000000e+00,  6.1232340e-17, -1.0000000e+00, -1.8369702e-16]), array([ 0.0000000e+00,  1.0000000e+00,  1.2246468e-16, -1.0000000e+00])]

# %%
n=4;
pts=10*npr.rand(n,2);
vor=Voronoi(pts);
voronoi_plot_2d(vor);
plt.show();
